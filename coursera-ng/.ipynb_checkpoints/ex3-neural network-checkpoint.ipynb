# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
from scipy.io import loadmat

# %%
data = loadmat('data-in/ex3data1.mat')
print(type(data))
# Out:
# <class 'dict'>

# %%
def load_data(data, transpose=True):
    y = data.get('y')
    X = data.get('X')
    
    if transpose:
        X = np.array([im.reshape(20,20).T for im in X])
        
        X = np.array([im.reshape(400) for  im in X])
        
    return X, y

# %%
X, y = load_data(data)

# %%
print(X.shape, y.shape)
# Out:
# (5000, 400) (5000, 1)

# %%
import matplotlib
def plot_an_image(image):
    """
    image:(400)
    """
    fig, ax = plt.subplots(figsize=(1,1))
    ax.matshow(image.reshape(20,20), cmap=matplotlib.cm.binary)
    plt.xticks(np.array([]))
    plt.yticks(np.array([]))

# %%
pick_one = np.random.randint(0,5000)

# %%
plot_an_image(X[pick_one, :])
print('this image should be %s' % pick_one)
# Out:
# this image should be 586

# %%
def plot_100_image(X):
    size = int(np.sqrt(X.shape[1]))
    print(size)
    
    sample_idx = np.random.choice(np.arange(X.shape[0]), 100)
    sample_images = X[sample_idx, :]
    
    fig, ax_array = plt.subplots(nrows=10, ncols=10, sharex=True, sharey=True, figsize=(8,8))
    
    for r in range(10):
        for c in range(10):
            ax_array[r,c].matshow(sample_images[10 * r + c].reshape(size,size), \
                                 cmap=matplotlib.cm.binary)
            plt.xticks(np.array([]))
            plt.yticks(np.array([]))

# %%
plot_100_image(X)
# Out:
# 20

# %% [markdown]
# ## prepare data

# %%
X = np.insert(X, 0, values=np.ones(X.shape[0]), axis=1)
X.shape
# Out:
# (5000, 401)

# %%
print(y.shape)
# Out:
# (5000, 1)

# %%
y = y.reshape(y.shape[0])
y_matrix = []

for k in range(1,11):
    y_matrix.append((y == k).astype(int))

y_matrix = [y_matrix[-1]] + [y_matrix[:-1]]
y = np.array(y_matrix)
y.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-5e5700835465> in <module>()
# ----> 1 y = y.reshape(y.shape[1])
#       2 y_matrix = []
#       3
#       4 for k in range(1,11):
#       5     y_matrix.append((y == k).astype(int))
#
# ValueError: cannot reshape array of size 5000 into shape (1,)
